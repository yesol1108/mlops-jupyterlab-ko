# %% [markdown]
# # Locust를 사용한 자동 확장 테스트 🐛
#
# Locust는 오픈 소스 성능/부하 테스트 도구입니다. 개발자 친화적인 접근 방식으로 일반적인 Python 코드로 테스트를 정의할 수 있습니다. 왼쪽 패널에서 볼 수 있는 `locustfile.py`는 모델 엔드포인트에 대한 요청의 정의입니다. Locust를 사용하면 해당 요청을 사용하여 2개의 동시 요청을 전송합니다.

# %%
# locust 라이브러리 설치
# !pip -q install locust

# %%
infer_endpoint = "ENTER-YOUR-INFERENCE-ENDPOINT"

# %% [markdown]
# #### 아래 셀을 실행한 다음 Locust가 모델로 요청을 전송하는 동안 지침으로 돌아가세요! 테스트 환경으로 리디렉션되고 모델 배포의 새로운 인스턴스가 시작됩니다! 🏃💨

# %%
# 테스트 엔드포인트로 locust 실행
# !locust --headless --users 2 --spawn-rate 1 -H {infer_endpoint} --run-time 50s
